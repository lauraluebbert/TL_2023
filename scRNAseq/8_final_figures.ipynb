# %% [markdown]
# # (Some of the) final plots for main figure of paper
# Data from jointly clustered datasets.

# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext blackcellmagic
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %%
import sys
import anndata
# import scvi

# import scanpy as sc
import numpy as np
from scipy import stats

from upsetplot import UpSet

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import cm

# Custom violinplot code
from plotting_funcs import violinplot

import gget

import pandas as pd

# sc.set_figure_params(figsize=(6, 6), frameon=False)
# sc.settings.n_jobs=2

# %%
# set random seed
np.random.seed(926)

# %%
def nd(arr):
    """
    Function to transform numpy matrix to nd array.
    """
    return np.asarray(arr).reshape(-1)

# %% [markdown]
# ___

# %% [markdown]
# # Load AnnData object

# %%
adata = anndata.read_h5ad("../../finchseq_data/all_celltype.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 35804 × 22151
#     obs: 'species', 'batch', 'n_counts_processed', 'batch_index', 'n_counts_raw', 'leiden', 'celltype', 'connectivity'
#     var: 'gene_name', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'batch_colors', 'celltype_colors', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# Define masks to separate control and experiment datasets:

# %%
control_mask = np.logical_or(adata.obs["batch"]=="control1", adata.obs["batch"]=="control2")
experiment_mask = np.logical_or(adata.obs["batch"]=="experiment1", adata.obs["batch"]=="experiment2")

# %% [markdown]
# Add new obs column to separate between control and experiment in general, without separating between batches:

# %%
adata.obs["batch_g"] = ""

adata.obs.loc[control_mask, "batch_g"] = "control"
adata.obs.loc[experiment_mask, "batch_g"] = "experiment"

# Create columns containing general celltype assignment - ignoring cluster separation
adata.obs['celltype_g'] = adata.obs['celltype'].str.replace('\d+', '')

adata.obs.head()
# Out:
# /home/lauraluebbert/bin/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys
#                        species     batch  n_counts_processed batch_index  \
# barcode
# AAACCCAAGCACTGGA-0  zebrafinch  control1          483.000000           0
# AAACCCAAGCGTCAAG-0  zebrafinch  control1          946.000061           0
# AAACCCAAGGTCACAG-0  zebrafinch  control1         1068.000000           0
# AAACCCAAGTCATTGC-0  zebrafinch  control1         1407.000000           0
# AAACCCAAGTGCTACT-0  zebrafinch  control1         1060.000000           0
#
#                     n_counts_raw leiden             celltype connectivity  \
# barcode
# AAACCCAAGCACTGGA-0    483.000000     13        mural cells 2            0
# AAACCCAAGCGTCAAG-0    946.000061      3          microglia 1            1
# AAACCCAAGGTCACAG-0   1068.000000      1  GABAergic neurons 1            2
# AAACCCAAGTCATTGC-0   1407.000000     10         astrocytes 2            3
# AAACCCAAGTGCTACT-0   1060.000000      1  GABAergic neurons 1            2
#
#                     batch_g          celltype_g
# barcode
# AAACCCAAGCACTGGA-0  control        mural cells
# AAACCCAAGCGTCAAG-0  control          microglia
# AAACCCAAGGTCACAG-0  control  GABAergic neurons
# AAACCCAAGTCATTGC-0  control         astrocytes
# AAACCCAAGTGCTACT-0  control  GABAergic neurons

# %% [markdown]
# Split experiment and control data into separate AnnData objects for violin plots:

# %%
adata_exp = adata[adata.obs.batch_g=="experiment"]
adata_ctrl = adata[adata.obs.batch_g=="control"]

# %% [markdown]
# Define standard set of celltypes to plot (excluding clusters with < 100 cells):

# %%
celltypes_standard = [
    "GABAergic neurons 1",
    "GABAergic neurons 2",
    "astrocytes 1",
    "astrocytes 2",
    "microglia 1",
    "microglia 2",
    "glutamatergic neurons 1",
    "glutamatergic neurons 2",
    "glutamatergic neurons 3",
    "glutamatergic neurons 4"
]

# %%
celltype_labels = [
    "GABAergic neurons 1",
    "GABAergic neurons 2",
    "Astrocytes 1",
    "Astrocytes 2",
    "Microglia 1",
    "Microglia 2",
    "Glutamatergic neurons 1",
    "Glutamatergic neurons 2",
    "Glutamatergic neurons 3",
    "Glutamatergic neurons 4",
]

# %% [markdown]
# ___

# %% [markdown]
# ## Does each celltype cluster contain an equal number of cells from each batch/dataset?

# %% [markdown]
# Let's look at the actual number of cells from each batch for each celltype:

# %%
# Normalize each celltype count to total number of cells in that batch by dividing
df_normalized = (adata.obs.groupby("celltype")["batch"].value_counts() / adata.obs.groupby("batch")["species"].count()).unstack().fillna(0)
df_normalized.columns = df_normalized.columns.astype(str)
df_normalized["total normalized count"] = df_normalized.sum(axis=1).values

df_normalized["control1_fraction"] = (df_normalized["control1"] / df_normalized["total normalized count"]).values
df_normalized["control2_fraction"] = (df_normalized["control2"] / df_normalized["total normalized count"]).values
df_normalized["experiment1_fraction"] = (df_normalized["experiment1"] / df_normalized["total normalized count"]).values
df_normalized["experiment2_fraction"] = (df_normalized["experiment2"] / df_normalized["total normalized count"]).values

df_normalized["total cellcount"] = adata.obs.groupby("celltype").size().values.astype(int)

df_normalized
# Out:
# batch                                 control1  control2  experiment1  \
# celltype
# GABAergic neurons 1                   0.118611  0.155614     0.109006
# GABAergic neurons 2                   0.047834  0.045312     0.034778
# GABAergic neurons 3                   0.002049  0.001819     0.001038
# astrocytes 1                          0.074465  0.049281     0.038541
# astrocytes 2                          0.024890  0.043327     0.029587
# glutamatergic neurons 1               0.134999  0.104845     0.111861
# glutamatergic neurons 2               0.113490  0.148338     0.060472
# glutamatergic neurons 3               0.041790  0.074252     0.077861
# glutamatergic neurons 4               0.009526  0.004630     0.005840
# microglia 1                           0.049472  0.032082     0.147677
# microglia 2                           0.032777  0.019679     0.090968
# microglia 3 / radial glia             0.000205  0.000165     0.001298
# migrating neuroblasts                 0.080713  0.110137     0.082922
# mural / vascular endothelial cells 1  0.067909  0.074582     0.066052
# mural cells 2                         0.027451  0.018356     0.019206
# oligodendrocyte precursor cells       0.015364  0.007938     0.013107
# oligodendrocytes 1                    0.041586  0.019845     0.024137
# oligodendrocytes 2                    0.009218  0.006119     0.003114
# oligodendrocytes 3                    0.002253  0.001819     0.001168
# radial glia 1                         0.084298  0.065652     0.067739
# radial glia 2                         0.010550  0.012072     0.006359
# red blood cells                       0.010550  0.004134     0.007267
#
# batch                                 experiment2  total normalized count  \
# celltype
# GABAergic neurons 1                      0.093180                0.476412
# GABAergic neurons 2                      0.040609                0.168532
# GABAergic neurons 3                      0.001628                0.006533
# astrocytes 1                             0.065511                0.227798
# astrocytes 2                             0.078288                0.176092
# glutamatergic neurons 1                  0.108236                0.459941
# glutamatergic neurons 2                  0.030518                0.352818
# glutamatergic neurons 3                  0.043376                0.237279
# glutamatergic neurons 4                  0.010579                0.030575
# microglia 1                              0.099609                0.328841
# microglia 2                              0.063802                0.207226
# microglia 3 / radial glia                0.000977                0.002644
# migrating neuroblasts                    0.101156                0.374928
# mural / vascular endothelial cells 1     0.061361                0.269905
# mural cells 2                            0.023926                0.088938
# oligodendrocyte precursor cells          0.014242                0.050650
# oligodendrocytes 1                       0.069824                0.155391
# oligodendrocytes 2                       0.005046                0.023497
# oligodendrocytes 3                       0.001546                0.006787
# radial glia 1                            0.057536                0.275225
# radial glia 2                            0.014811                0.043792
# red blood cells                          0.014242                0.036193
#
# batch                                 control1_fraction  control2_fraction  \
# celltype
# GABAergic neurons 1                            0.248968           0.326638
# GABAergic neurons 2                            0.283825           0.268861
# GABAergic neurons 3                            0.313551           0.278429
# astrocytes 1                                   0.326890           0.216335
# astrocytes 2                                   0.141346           0.246049
# glutamatergic neurons 1                        0.293515           0.227954
# glutamatergic neurons 2                        0.321667           0.420438
# glutamatergic neurons 3                        0.176123           0.312930
# glutamatergic neurons 4                        0.311552           0.151443
# microglia 1                                    0.150445           0.097561
# microglia 2                                    0.158169           0.094965
# microglia 3 / radial glia                      0.077465           0.062535
# migrating neuroblasts                          0.215276           0.293756
# mural / vascular endothelial cells 1           0.251605           0.276328
# mural cells 2                                  0.308647           0.206392
# oligodendrocyte precursor cells                0.303338           0.156719
# oligodendrocytes 1                             0.267618           0.127707
# oligodendrocytes 2                             0.392322           0.260402
# oligodendrocytes 3                             0.332036           0.268039
# radial glia 1                                  0.306287           0.238540
# radial glia 2                                  0.240912           0.275669
# red blood cells                                0.291494           0.114229
#
# batch                                 experiment1_fraction  \
# celltype
# GABAergic neurons 1                               0.228806
# GABAergic neurons 2                               0.206359
# GABAergic neurons 3                               0.158899
# astrocytes 1                                      0.169191
# astrocytes 2                                      0.168022
# glutamatergic neurons 1                           0.243207
# glutamatergic neurons 2                           0.171398
# glutamatergic neurons 3                           0.328143
# glutamatergic neurons 4                           0.190992
# microglia 1                                       0.449084
# microglia 2                                       0.438980
# microglia 3 / radial glia                         0.490717
# migrating neuroblasts                             0.221169
# mural / vascular endothelial cells 1              0.244725
# mural cells 2                                     0.215945
# oligodendrocyte precursor cells                   0.258769
# oligodendrocytes 1                                0.155331
# oligodendrocytes 2                                0.132546
# oligodendrocytes 3                                0.172091
# radial glia 1                                     0.246123
# radial glia 2                                     0.145202
# red blood cells                                   0.200787
#
# batch                                 experiment2_fraction  total cellcount
# celltype
# GABAergic neurons 1                               0.195588             4084
# GABAergic neurons 2                               0.240955             1508
# GABAergic neurons 3                               0.249121               59
# astrocytes 1                                      0.287584             2127
# astrocytes 2                                      0.444584             1695
# glutamatergic neurons 1                           0.235325             4144
# glutamatergic neurons 2                           0.086497             2846
# glutamatergic neurons 3                           0.182804             1990
# glutamatergic neurons 4                           0.346013              296
# microglia 1                                       0.302910             3039
# microglia 2                                       0.307886             1924
# microglia 3 / radial glia                         0.369284               25
# migrating neuroblasts                             0.269800             3336
# mural / vascular endothelial cells 1              0.227342             2377
# mural cells 2                                     0.269015              821
# oligodendrocyte precursor cells                   0.281175              474
# oligodendrocytes 1                                0.449344             1570
# oligodendrocytes 2                                0.214730              213
# oligodendrocytes 3                                0.227834               61
# radial glia 1                                     0.209050             2449
# radial glia 2                                     0.338217              407
# red blood cells                                   0.393490              359

# %%
# Only keep celltypes to plot
df_normalized = df_normalized.loc[celltypes_standard]

# %% [markdown]
# Function to plot ln(FC):

# %%
def plot_lnfc(ax):
    exp = df_normalized[["experiment1", "experiment2"]].sum(axis=1)
    ctrl = df_normalized[["control1", "control2"]].sum(axis=1)

    x = df_normalized.index.values
    y = []
    cell_counts = df_normalized["total cellcount"].values
    cell_color = "navy"

    counter = 0
    del_idx = []

    # Calculate log(fold change)
    for i, exp_value in enumerate(exp):
        if cell_counts[i] < 100:
            # Collect indeces of labels to delete from x labels
            del_idx.append(i)
            continue
        else:
            y_temp = np.log(exp_value / ctrl[i])
            y.append(y_temp)
            if exp_value >= ctrl[i]:
                ax.text(x = counter, y = y_temp + 0.1, s = cell_counts[i], size = 8, ha='center', c=cell_color)
            if ctrl[i] >= exp_value:
                ax.text(x = counter, y = y_temp - 0.25, s = cell_counts[i], size = 8, ha='center', c=cell_color)
            counter +=1

    x = np.delete(x, del_idx)

    # Plot stem/scatter plot
    ax.vlines(x, 0, y, color="black", linestyle="-", lw=1, zorder=-1)
    ax.scatter(x , y, c="black", s=30)

    ax.set(
        **{
            "title": "ln(Fold Change) in cell count between TeNT and control",
            "ylabel": "ln(cellcount$_{TeNT}$ / cellcount$_{control}$)",
            "ylim": (-1.7, 1.7)
            #     "xlabel": "Celltypes"
        }
    )

    ax.axhline(y=0, color="black", linestyle="-", lw=1, zorder=-1)
    ax.set_xticklabels(celltype_labels, rotation=45, ha="right")

    ax.text(-0.2, np.log(3)+0.05, "Fold Change = 3", ha="left", size=10, c='red')
    ax.axhline(y=np.log(3), color="red", linestyle="--", lw=1, zorder=-1)
    ax.axhline(y=-np.log(3), color="red", linestyle="--", lw=1, zorder=-1)

    # Add blocks and text separating each comparison category
    ax.axhspan(-1.7, 0, facecolor='aliceblue', alpha=0.5, zorder=-1)
    ax.axhspan(0, 1.7, facecolor='moccasin', alpha=0.5, zorder=-1)
    ax.text(-0.2, -1.55, "cellcount$_{control}$ > cellcount$_{TeNT}$", ha="left", size=10)
    ax.text(-0.2, 1.45, "cellcount$_{TeNT}$ > cellcount$_{control}$", ha="left", size=10)
    ax.text(9.2, 1.45, "Total number of cells in cluster", ha="right", c=cell_color, size=10)

    ax.margins(x=0.03, y=0.01)
    ax.grid(False)
    ax.xaxis.grid(color='gray', ls='--', lw=0.1)
    ax.yaxis.grid(color='gray', ls='--', lw=0.1)
    ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(figsize = (15, 3))

plot_lnfc(ax)

fig.savefig("figures/final/8_cluster_abundance.svg", dpi=300, bbox_inches="tight")
fig.savefig("figures/final/8_cluster_abundance.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ___
# Same plot but without splitting celltype clusters belonging to the same celltype:

# %%
# Normalize each celltype count to total number of cells in that batch by dividing
df_norm_g = (adata.obs.groupby("celltype_g")["batch"].value_counts() / adata.obs.groupby("batch")["species"].count()).unstack().fillna(0)
df_norm_g.columns = df_norm_g.columns.astype(str)
df_norm_g["total normalized count"] = df_norm_g.sum(axis=1).values

df_norm_g["control1_fraction"] = (df_norm_g["control1"] / df_norm_g["total normalized count"]).values
df_norm_g["control2_fraction"] = (df_norm_g["control2"] / df_norm_g["total normalized count"]).values
df_norm_g["experiment1_fraction"] = (df_norm_g["experiment1"] / df_norm_g["total normalized count"]).values
df_norm_g["experiment2_fraction"] = (df_norm_g["experiment2"] / df_norm_g["total normalized count"]).values

df_norm_g["total cellcount"] = adata.obs.groupby("celltype_g").size().values.astype(int)

df_norm_g
# Out:
# batch                                control1  control2  experiment1  \
# celltype_g
# GABAergic neurons                    0.168493  0.202745     0.144822
# astrocytes                           0.099355  0.092608     0.068129
# glutamatergic neurons                0.299805  0.332065     0.256034
# microglia                            0.082249  0.051761     0.238645
# microglia  / radial glia             0.000205  0.000165     0.001298
# migrating neuroblasts                0.080713  0.110137     0.082922
# mural / vascular endothelial cells   0.067909  0.074582     0.066052
# mural cells                          0.027451  0.018356     0.019206
# oligodendrocyte precursor cells      0.015364  0.007938     0.013107
# oligodendrocytes                     0.053057  0.027782     0.028419
# radial glia                          0.094848  0.077724     0.074098
# red blood cells                      0.010550  0.004134     0.007267
#
# batch                                experiment2  total normalized count  \
# celltype_g
# GABAergic neurons                       0.135417                0.651477
# astrocytes                              0.143799                0.403890
# glutamatergic neurons                   0.192708                1.080613
# microglia                               0.163411                0.536067
# microglia  / radial glia                0.000977                0.002644
# migrating neuroblasts                   0.101156                0.374928
# mural / vascular endothelial cells      0.061361                0.269905
# mural cells                             0.023926                0.088938
# oligodendrocyte precursor cells         0.014242                0.050650
# oligodendrocytes                        0.076416                0.185675
# radial glia                             0.072347                0.319017
# red blood cells                         0.014242                0.036193
#
# batch                                control1_fraction  control2_fraction  \
# celltype_g
# GABAergic neurons                             0.258633           0.311208
# astrocytes                                    0.245994           0.229290
# glutamatergic neurons                         0.277440           0.307293
# microglia                                     0.153431           0.096557
# microglia  / radial glia                      0.077465           0.062535
# migrating neuroblasts                         0.215276           0.293756
# mural / vascular endothelial cells            0.251605           0.276328
# mural cells                                   0.308647           0.206392
# oligodendrocyte precursor cells               0.303338           0.156719
# oligodendrocytes                              0.285754           0.149629
# radial glia                                   0.297313           0.243637
# red blood cells                               0.291494           0.114229
#
# batch                                experiment1_fraction  \
# celltype_g
# GABAergic neurons                                0.222298
# astrocytes                                       0.168681
# glutamatergic neurons                            0.236934
# microglia                                        0.445178
# microglia  / radial glia                         0.490717
# migrating neuroblasts                            0.221169
# mural / vascular endothelial cells               0.244725
# mural cells                                      0.215945
# oligodendrocyte precursor cells                  0.258769
# oligodendrocytes                                 0.153060
# radial glia                                      0.232270
# red blood cells                                  0.200787
#
# batch                                experiment2_fraction  total cellcount
# celltype_g
# GABAergic neurons                                0.207861             5651
# astrocytes                                       0.356034             3822
# glutamatergic neurons                            0.178332             9276
# microglia                                        0.304834             4963
# microglia  / radial glia                         0.369284               25
# migrating neuroblasts                            0.269800             3336
# mural / vascular endothelial cells               0.227342             2377
# mural cells                                      0.269015              821
# oligodendrocyte precursor cells                  0.281175              474
# oligodendrocytes                                 0.411557             1844
# radial glia                                      0.226781             2856
# red blood cells                                  0.393490              359

# %% [markdown]
# Function to plot ln(FC):

# %%
celltype_names = [
    'GABAergic neurons',
    'Astrocytes',
    'Glutamatergic neurons',
    'Microglia',
    'Microglia/radial glia',
    'Migrating neuroblasts',
    'Mural/vascular\nendothelial cells',
    'Mural cells',
    'Oligodendrocyte\nprecursor cells',
    'Oligodendrocytes',
    'Radial glia',
    'Red blood cells'
]

# %%
def plot_lnfc(ax):
    fontsize = 14
    exp = df_norm_g[["experiment1", "experiment2"]].sum(axis=1)
    ctrl = df_norm_g[["control1", "control2"]].sum(axis=1)

    x = df_norm_g.index.values
    y = []
    cell_counts = df_norm_g["total cellcount"].values
    cell_color = "navy"

    counter = 0
    del_idx = []

    # Calculate log(fold change)
    for i, exp_value in enumerate(exp):
        if cell_counts[i] < 100:
            # Collect indeces of labels to delete from x labels
            del_idx.append(i)
            continue
        else:
            y_temp = np.log(exp_value / ctrl[i])
            y.append(y_temp)
            if exp_value >= ctrl[i]:
                ax.text(x = counter, y = y_temp + 0.075, s = cell_counts[i], size = fontsize-3, ha='center', c=cell_color)
            if ctrl[i] >= exp_value:
                ax.text(x = counter, y = y_temp - 0.18, s = cell_counts[i], size = fontsize-3, ha='center', c=cell_color)
            counter +=1

    x = np.delete(x, del_idx)

    # Plot stem/scatter plot
    ax.vlines(x, 0, y, color="black", linestyle="-", lw=2, zorder=-1)
    ax.scatter(x , y, c="black", s=100)

    ax.set_title("ln(Fold Change) in cell count between TeNT and control", fontsize=fontsize+2)
    ax.set_ylim((-1.7, 1.7))
    ax.set_ylabel("ln(cellcount$_{TeNT}$ / cellcount$_{control}$)", fontsize=fontsize)

    ax.axhline(y=0, color="black", linestyle="-", lw=1, zorder=-1)
    ax.set_xticklabels(celltype_names, rotation=45, ha="right")
    ax.tick_params(axis='both', labelsize=fontsize)

    ax.text(-0.2, np.log(3)+0.05, "Fold Change = 3", ha="left", size=fontsize-2, c='red')
    ax.axhline(y=np.log(3), color="red", linestyle="--", lw=1.5, zorder=-1)
    ax.axhline(y=-np.log(3), color="red", linestyle="--", lw=1.5, zorder=-1)

    # Add blocks and text separating each comparison category
    ax.axhspan(-1.7, 0, facecolor='lightblue', alpha=0.6, zorder=-1)
    ax.axhspan(0, 1.7, facecolor='red', alpha=0.1, zorder=-1)
    ax.text(-0.2, -1.6, "cellcount$_{control}$ > cellcount$_{TeNT}$", ha="left", size=fontsize-2)
    ax.text(-0.2, 1.55, "cellcount$_{TeNT}$ > cellcount$_{control}$", ha="left", size=fontsize-2)
    ax.text(10.2, 1.55, "Total number of cells", ha="right", c=cell_color, size=fontsize-2)

    ax.margins(x=0.03, y=0.01)
    ax.grid(False)
    ax.xaxis.grid(color='gray', ls='--', lw=0.1)
    ax.yaxis.grid(color='gray', ls='--', lw=0.1)
    ax.set_axisbelow(True)

# %%
fig, ax = plt.subplots(figsize = (10, 7))

plot_lnfc(ax)

fig.savefig("figures/final/8_celltype_abundance.svg", dpi=300, bbox_inches="tight")
fig.savefig("figures/final/8_celltype_abundance.pdf", dpi=300, bbox_inches="tight")
fig.savefig("figures/final/8_celltype_abundance.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ___

# %% [markdown]
# # Violin plot of MHC1/B2M expression
# Function to plot violin plots:

# %%
import numpy as np
from scipy import stats

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import pandas as pd

def nd(arr):
    """
    Funciton to transform numpy matrix to nd array.
    """
    return np.asarray(arr).reshape(-1)

def violinplot(adata_exp, adata_ctrl, genes, labels, celltypes, celltype_labels, axs, alpha=0.05, fold_change_min=2):
    ## Find the indeces of the celltypes/clusters to be used
    # If the first celltype does not contain a number (e.g. "microglia" versus "microglia_1"),
    # use general celltype (celltype_g) to find all of the clusters for that celltye
    # (This is the case for data from the separately clustered dataset)
    if any(map(str.isdigit, celltypes[0])) == False:
        print("Including all clusters for each celltype (obs column: celltype_g).")
        # Define celltypes and celltype indeces in both datasets
        celltype_exp_idx = [np.where(adata_exp.obs.celltype_g == i)[0] for i in celltypes]
        celltype_ctrl_idx = [np.where(adata_ctrl.obs.celltype_g == i)[0] for i in celltypes]
    # Else, use individual clusters
    else:
        print("Individual cluster analysis (obs column: celltype).")
        # Define celltypes and celltype indeces in both datasets
        celltype_exp_idx = [np.where(adata_exp.obs.celltype == i)[0] for i in celltypes]
        celltype_ctrl_idx = [np.where(adata_ctrl.obs.celltype == i)[0] for i in celltypes]

    lidx = np.arange(len(celltypes))*2
    
    fontsize_star = 20
    
    if len(genes) < 2:
        axs = [axs]

    for cidx, (gene, ax) in enumerate(zip(genes, axs)):
        ## Get counts for this gene for all EXP cells
        x_exp_temp = nd(adata_exp.X[:, adata_exp.var.index.str.contains(gene)].todense())
        # Group EXP normalized UMI counts per celltype
        x_exp=[]
        for idx_array in celltype_exp_idx:
            x_exp.append([x_exp_temp[i] for i in idx_array])

        v1 = ax.violinplot(x_exp, showmedians=False, showextrema=False, positions=lidx+0.3)

        ## Get counts for this gene for all CTRL cells
        x_ctrl_temp = nd(adata_ctrl.X[:, adata_ctrl.var.index.str.contains(gene)].todense())
        # Group CTRL normalized UMI counts per celltype
        x_ctrl=[]
        for idx_array in celltype_ctrl_idx:
            x_ctrl.append([x_ctrl_temp[i] for i in idx_array])

        v2 = ax.violinplot(x_ctrl, showmedians=False, showextrema=False, positions=lidx-0.3)
          
        ## Welch's t-test and fold change of mean calculation
        fold_changes = [] 
        p_values = []
        for index, cell_array in enumerate(x_exp):
            # Perform Welch’s t-test, which does not assume equal population variance
            s, p = stats.ttest_ind(cell_array, x_ctrl[index], equal_var=False)
            # Save p-value for violin plot body transparency and heatmap
            p_values.append(p)
            
            if np.mean(cell_array) > np.mean(x_ctrl[index]):
                fold_change = np.mean(cell_array) / np.mean(x_ctrl[index])
                if p < alpha and fold_change >= fold_change_min:
                    ax.annotate("*", (lidx[index], 0.5*ax.get_ylim()[1]), ha="center", c="black", fontsize=fontsize_star)
                    
                # Save foldchange for violin plot body transparency and heatmap
                fold_changes.append(fold_change)
                    
            if np.mean(cell_array) <= np.mean(x_ctrl[index]):
                fold_change = np.mean(x_ctrl[index]) / np.mean(cell_array)
                if p < alpha and fold_change >= fold_change_min:
                    ax.annotate("*", (lidx[index], 0.5*ax.get_ylim()[1]), ha="center", c="black", fontsize=fontsize_star)
                    
                # Save foldchange for violin plot body transparency and heatmap
                fold_changes.append(fold_change)
                    
        ## Set color and transparency of the violin plot bodies
        # Set transparency based on fold change (FC) and p-value
        # All violin plots showing an FC >= fold_change_min and p < alpha will be 100% opaque; 
        # for FCs < fold_change_min and p > alpha will be 10% opaque
        # Violin plots showing experiment data:
        for pcidx, pc in enumerate(v1["bodies"]):
            pc.set_facecolor(exp_color)  
            pc.set_edgecolor("black")
            if fold_changes[pcidx] >= fold_change_min and p_values[pcidx] < alpha:
                pc.set_alpha(1)
            else:
                pc.set_alpha(0.1)
        # Violin plots showing control data:
        for pcidx2, pc2 in enumerate(v2["bodies"]):
            pc2.set_facecolor(control_color)
            pc2.set_edgecolor("black")
            if fold_changes[pcidx2] >= fold_change_min and p_values[pcidx2] < alpha:
                pc2.set_alpha(1)
            else:
                pc2.set_alpha(0.1)

        ## Set up x- and y- tick labels, and distinct top and bottom axes  
        # Get total number of cells per celltype cluster
        cellcounts_exp=[]
        for array in x_exp:
            cellcounts_exp.append(len(array)) 
        cellcounts_ctrl=[]
        for array in x_ctrl:
            cellcounts_ctrl.append(len(array)) 

        xticklabels=[]    
        for i2, (celltype_label, cellcount) in enumerate(zip(celltype_labels, cellcounts_exp)):
            xticklabels.append("{} \n(Control: {}; TeNT: {})".format(celltype_label, cellcounts_ctrl[i2], cellcount))

        if cidx==0:
            ax_top = ax.twiny()
            ax_top.set_xlim(ax.get_xlim()) # DO NOT DELETE THIS
            ax_top.set_ylim(ax.get_ylim()[0], 2.5*ax.get_ylim()[1]) # Slightly increase space on top of first row of plots
            ax_top.set_xticks(lidx)
            ax_top.set_xticklabels(xticklabels, rotation=45, ha="left", fontsize=13)
            ax_top.spines["top"].set_visible(False)
            ax_top.spines["left"].set_visible(False)
            ax_top.spines["bottom"].set_visible(False)
            ax_top.xaxis.grid(False) 

        if cidx == len(genes)-1:
            ax_bot = ax.twiny()
            ax_bot.set_xticks([])
            ax_bot.set_xticklabels([])
            ax_bot.spines["top"].set_visible(False)
            ax_bot.spines["left"].set_visible(False)
            ax_bot.spines["bottom"].set_visible(False)

        ax.yaxis.tick_right()
        ax.set_ylabel(labels[cidx], color="black",rotation="horizontal", ha="right", va="center", fontsize=fontsize)

        ax.spines["top"].set_visible(False)
        ax.spines["left"].set_visible(False)
        ax.spines["bottom"].set_visible(False)

        ax.set_axisbelow(True)
        ax.xaxis.grid(False) 
        
        # Set y axis on log scale including 0
        ax.set_yscale('symlog')

        ax.tick_params(
            axis="x",          # changes apply to the x-axis
            which="both",      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False,         # ticks along the top edge are off
            labelbottom=False) # labels along the bottom edge are off

# %%
# Define genes and labels for violin plot
mhc_genes = ["_ENSTGUG00000017273.2", "_ENSTGUG00000004607.2"]
mhc_gene_names = ["MHC1", "B2M"]

# %% [markdown]
# Note: Regulation of CNS synapses by neuronal MHC class I https://pubmed.ncbi.nlm.nih.gov/17420446/
#
# Abbreviations:
# MHC1 = Major Histocompatibility Complex, Class I (alpha chain-like)
# B2M = Beta-2-Microglobulin

# %%
# Set violin plot parameters
genes = mhc_genes
labels = mhc_gene_names
celltypes = celltypes_standard

fig, axs = plt.subplots(figsize = (15, 3), nrows=len(genes))

fontsize = 13
control_color = "blue"
exp_color = "red"

# Plot violin plot
violinplot(
    adata_exp,
    adata_ctrl,
    genes,
    labels,
    celltypes,
    celltype_labels = celltype_labels,
    axs=axs,
    fold_change_min=1.5,
)

fig.savefig("figures/final/8_mhc_b2m.svg", dpi=300, bbox_inches="tight")
fig.savefig("figures/final/8_mhc_b2m.pdf", dpi=300, bbox_inches="tight")
fig.savefig("figures/final/8_mhc_b2m.png", dpi=300, bbox_inches="tight")
# Out:
# Individual cluster analysis (obs column: celltype).
