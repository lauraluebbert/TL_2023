# %%
# !date
# Out:
# Thu Dec 23 08:53:34 PST 2021

# %% [markdown]
# # Check for expression of Alex' potential markers in separately clustered CTRL data
# #### Unfiltered data obtained from using kb with multimapping function. Ref genome includes WRE.

# %% [markdown]
# ___

# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext blackcellmagic

# %%
import sys
import anndata
import scvi

import scanpy as sc
import numpy as np
from scipy import stats

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

import pandas as pd

sc.set_figure_params(figsize=(6, 6), frameon=False)
sc.settings.n_jobs=2

# %%
# set random seed
np.random.seed(926)

# %%
def nd(arr):
    """
    Funciton to transform numpy matrix to nd array.
    """
    return np.asarray(arr).reshape(-1)

# %% [markdown]
# ___

# %% [markdown]
# # Load clustered and celltype assigned ctrl/experiment data

# %%
adata = anndata.read('../../finchseq_data/ctrl_celltype.h5ad')

# Mark celltype and connectivity with "c" for control
adata.obs["batch_g"] = "control"
adata.obs["celltype_sep"] = adata_ctrl.obs["celltype"].astype(str) + "_c"
adata.obs["connectivity_sep"] = adata_ctrl.obs["connectivity"].astype(str) + "_c"
adata.obs
# Out:
#                        species     batch  n_counts_processed batch_index  \
# barcode
# AAACCCAAGCACTGGA-0  zebrafinch  control1          483.000000           0
# AAACCCAAGCGTCAAG-0  zebrafinch  control1          946.000061           0
# AAACCCAAGGTCACAG-0  zebrafinch  control1         1068.000000           0
# AAACCCAAGTCATTGC-0  zebrafinch  control1         1407.000000           0
# AAACCCAAGTGCTACT-0  zebrafinch  control1         1060.000000           0
# ...                        ...       ...                 ...         ...
# TTTGTTGCAAATAAGC-1  zebrafinch  control2          663.000000           1
# TTTGTTGCAGTTGTCA-1  zebrafinch  control2         1120.000000           1
# TTTGTTGCATCGATAC-1  zebrafinch  control2         1177.000000           1
# TTTGTTGGTTACGTAC-1  zebrafinch  control2         2777.000000           1
# TTTGTTGTCCGATAGT-1  zebrafinch  control2          528.000000           1
#
#                     n_counts_raw leiden                 celltype connectivity  \
# barcode
# AAACCCAAGCACTGGA-0    483.000000     15            mural cells 1            0
# AAACCCAAGCGTCAAG-0    946.000061     12              microglia 1            1
# AAACCCAAGGTCACAG-0   1068.000000      1      GABAergic neurons 1            2
# AAACCCAAGTCATTGC-0   1407.000000      9             astrocytes 2            3
# AAACCCAAGTGCTACT-0   1060.000000     11      GABAergic neurons 2            4
# ...                          ...    ...                      ...          ...
# TTTGTTGCAAATAAGC-1    663.000000      0  glutamatergic neurons 1  undefined 1
# TTTGTTGCAGTTGTCA-1   1120.000000      9             astrocytes 2            3
# TTTGTTGCATCGATAC-1   1177.000000      9             astrocytes 2            3
# TTTGTTGGTTACGTAC-1   2777.000000      3            radial glia 1           13
# TTTGTTGTCCGATAGT-1    528.000000      0  glutamatergic neurons 1  undefined 1
#
#                     batch_g               celltype_sep connectivity_sep
# barcode
# AAACCCAAGCACTGGA-0  control            mural cells 1_c              0_c
# AAACCCAAGCGTCAAG-0  control              microglia 1_c              1_c
# AAACCCAAGGTCACAG-0  control      GABAergic neurons 1_c              2_c
# AAACCCAAGTCATTGC-0  control             astrocytes 2_c              3_c
# AAACCCAAGTGCTACT-0  control      GABAergic neurons 2_c              4_c
# ...                     ...                        ...              ...
# TTTGTTGCAAATAAGC-1  control  glutamatergic neurons 1_c    undefined 1_c
# TTTGTTGCAGTTGTCA-1  control             astrocytes 2_c              3_c
# TTTGTTGCATCGATAC-1  control             astrocytes 2_c              3_c
# TTTGTTGGTTACGTAC-1  control            radial glia 1_c             13_c
# TTTGTTGTCCGATAGT-1  control  glutamatergic neurons 1_c    undefined 1_c
#
# [15810 rows x 11 columns]

# %% [markdown]
# ___

# %% [markdown]
# # Load marker list and find markers in genome

# %%
markers = pd.read_csv('markers_Alex.txt', header = None)
markers.head()
# Out:
#                     0
# 0               ENPP1
# 1  ENSTGUG00000013568
# 2               CENPW
# 3  ENSTGUG00000028413
# 4              KLHL14

# %% [markdown]
# Find gene ID for each gene:

# %%
markers["gene_name_id"] = np.arange(len(markers[0].values))

# %%
# index counter
i = 0

for gene in markers[0].values:
    gene_name_id = []
    
    if gene.startswith("ENS"):
        gni = adata.var.iloc[np.where(adata.var.index.str.contains(gene))]
    
    else:
        gni = adata.var.iloc[np.where(adata.var.index.str.startswith(gene))]

    if len(gni) > 0:
        gene_name_id = gni.index[0]
    else:
        gene_name_id = np.nan

    markers["gene_name_id"][i] = gene_name_id
    i += 1
# Out:
# /home/lauraluebbert/bin/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/lauraluebbert/bin/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# Notes:
# MRVI1 found as IRAG1 ENSTGUG00000007955 on Ensembl
# CMYA5 matched to "novel gene" ENSTGUG00000028894 on Ensembl

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
markers
# Out:
#                      0                   gene_name_id
# 0                ENPP1     ENPP1_ENSTGUG00000011628.2
# 1   ENSTGUG00000013568          _ENSTGUG00000013568.2
# 2                CENPW     CENPW_ENSTGUG00000027690.1
# 3   ENSTGUG00000028413          _ENSTGUG00000028413.1
# 4               KLHL14    KLHL14_ENSTGUG00000010774.2
# 5   ENSTGUG00000015726          _ENSTGUG00000015726.2
# 6   ENSTGUG00000027036          _ENSTGUG00000027036.1
# 7   ENSTGUG00000028768          _ENSTGUG00000028768.1
# 8              TMPRSS7   TMPRSS7_ENSTGUG00000013593.2
# 9   ENSTGUG00000019134          _ENSTGUG00000019134.1
# 10             SLC4A11   SLC4A11_ENSTGUG00000011004.2
# 11  ENSTGUG00000019220          _ENSTGUG00000019220.1
# 12  ENSTGUG00000010481          _ENSTGUG00000010481.2
# 13               STYK1     STYK1_ENSTGUG00000012052.2
# 14               CDHR1     CDHR1_ENSTGUG00000006019.2
# 15               RSPO3     RSPO3_ENSTGUG00000011771.2
# 16               VIPR1     VIPR1_ENSTGUG00000025240.1
# 17               ESYT3     ESYT3_ENSTGUG00000011515.2
# 18              SRD5A2    SRD5A2_ENSTGUG00000008454.2
# 19                SYT9      SYT9_ENSTGUG00000005148.2
# 20  ENSTGUG00000020835          _ENSTGUG00000020835.1
# 21             COL12A1   COL12A1_ENSTGUG00000012648.2
# 22  ENSTGUG00000011376          _ENSTGUG00000011376.2
# 23                PLS1      PLS1_ENSTGUG00000008588.2
# 24  ENSTGUG00000010855          _ENSTGUG00000010855.2
# 25              PPARG_     PPARG_ENSTGUG00000004069.2
# 26                 LPL       LPL_ENSTGUG00000000287.2
# 27                NCF4      NCF4_ENSTGUG00000010694.2
# 28               IGF2_      IGF2_ENSTGUG00000009330.2
# 29               PRDM5     PRDM5_ENSTGUG00000001920.2
# 30                NDNF      NDNF_ENSTGUG00000001927.2
# 31               LAMA2     LAMA2_ENSTGUG00000011732.2
# 32              GPR157    GPR157_ENSTGUG00000003771.2
# 33  ENSTGUG00000026232          _ENSTGUG00000026232.1
# 34                SVIL      SVIL_ENSTGUG00000001028.2
# 35                PKIB      PKIB_ENSTGUG00000029133.1
# 36            ADAMTS18  ADAMTS18_ENSTGUG00000009163.2
# 37  ENSTGUG00000009611          _ENSTGUG00000009611.2
# 38            ADAMTS2_   ADAMTS2_ENSTGUG00000001108.2
# 39             FAM124A   FAM124A_ENSTGUG00000023086.1
# 40  ENSTGUG00000027489          _ENSTGUG00000027489.1
# 41               WNT5B     WNT5B_ENSTGUG00000012595.2
# 42  ENSTGUG00000025412          _ENSTGUG00000025412.1
# 43                FRZB      FRZB_ENSTGUG00000011320.2
# 44  ENSTGUG00000025124          _ENSTGUG00000025124.1
# 45                CD99      CD99_ENSTGUG00000021199.1
# 46               KCNB2     KCNB2_ENSTGUG00000011511.2
# 47               CALCR     CALCR_ENSTGUG00000001514.2
# 48                DRD3      DRD3_ENSTGUG00000013405.2
# 49               WNT7B     WNT7B_ENSTGUG00000021380.1
# 50               ZFPM2     ZFPM2_ENSTGUG00000012190.2
# 51  ENSTGUG00000007955     IRAG1_ENSTGUG00000007955.2
# 52               ITPKA     ITPKA_ENSTGUG00000010850.2
# 53               BARX2     BARX2_ENSTGUG00000000574.2
# 54               RSPO2     RSPO2_ENSTGUG00000012214.2
# 55                 DCN       DCN_ENSTGUG00000008178.2
# 56  ENSTGUG00000029543          _ENSTGUG00000029543.1
# 57              CAMKK1    CAMKK1_ENSTGUG00000004191.2
# 58               CDH17     CDH17_ENSTGUG00000011871.2
# 59               SCML2     SCML2_ENSTGUG00000007781.2
# 60  ENSTGUG00000024144          _ENSTGUG00000024144.1
# 61                CDS1      CDS1_ENSTGUG00000002118.2
# 62             SLC18A2   SLC18A2_ENSTGUG00000011058.2
# 63               ABCC8     ABCC8_ENSTGUG00000008682.2
# 64  ENSTGUG00000029493          _ENSTGUG00000029493.1
# 65               PDE5A     PDE5A_ENSTGUG00000001899.2
# 66             ZNF804B   ZNF804B_ENSTGUG00000001424.2
# 67              RHBDL3    RHBDL3_ENSTGUG00000028697.1
# 68              ADORA1    ADORA1_ENSTGUG00000001381.2
# 69  ENSTGUG00000021142          _ENSTGUG00000021142.1
# 70  ENSTGUG00000029265          _ENSTGUG00000029265.1
# 71  ENSTGUG00000019962          _ENSTGUG00000019962.1
# 72              BMPR1B    BMPR1B_ENSTGUG00000003164.2
# 73  ENSTGUG00000021509          _ENSTGUG00000021509.1
# 74  ENSTGUG00000024723          _ENSTGUG00000024723.1
# 75  ENSTGUG00000027346          _ENSTGUG00000027346.1
# 76  ENSTGUG00000026255          _ENSTGUG00000026255.1
# 77  ENSTGUG00000021175          _ENSTGUG00000021175.1
# 78  ENSTGUG00000020743          _ENSTGUG00000020743.1
# 79              SCUBE1    SCUBE1_ENSTGUG00000012016.2
# 80  ENSTGUG00000025369          _ENSTGUG00000025369.1
# 81               SGPP2     SGPP2_ENSTGUG00000007779.2
# 82              PTCHD4    PTCHD4_ENSTGUG00000013208.2
# 83             SLC24A2   SLC24A2_ENSTGUG00000004321.2
# 84  ENSTGUG00000000478          _ENSTGUG00000000478.2
# 85  ENSTGUG00000028337          _ENSTGUG00000028337.1
# 86  ENSTGUG00000000531          _ENSTGUG00000000531.2
# 87             SLC24A4   SLC24A4_ENSTGUG00000021487.1
# 88  ENSTGUG00000003202          _ENSTGUG00000003202.2
# 89  ENSTGUG00000028894          _ENSTGUG00000028894.1
# 90               CNTN4     CNTN4_ENSTGUG00000010102.2
# 91  ENSTGUG00000020554          _ENSTGUG00000020554.1
# 92  ENSTGUG00000027948          _ENSTGUG00000027948.1
# 93                ANO4      ANO4_ENSTGUG00000009008.2
# 94              SORCS3    SORCS3_ENSTGUG00000010448.2
# 95  ENSTGUG00000026201          _ENSTGUG00000026201.1
# 96                 TOX       TOX_ENSTGUG00000011174.2
# 97               SKAP2     SKAP2_ENSTGUG00000002889.2
# 98                SV2B      SV2B_ENSTGUG00000008436.2
# 99  ENSTGUG00000009316   ZNF385B_ENSTGUG00000009316.2

# %% [markdown]
# ____

# %% [markdown]
# # Plot expression of potential markers in glut neurons

# %%
all_markers = np.concatenate((["SLC17A6_ENSTGUG00000004570.2", "SCN3B_ENSTGUG00000000607.2"], markers["gene_name_id"].values))

# %%
sc.pl.heatmap(
    adata[np.char.startswith(nd(adata.obs.celltype.values).astype(str), "glutamatergic neurons")],
    all_markers,
    groupby="connectivity",
#     dendrogram=True, # This messes up the ordering of the celltypes
    show_gene_labels=True,
#     var_group_positions=var_groups,
#     var_group_labels=var_labels,
#     var_group_rotation=90,
    use_raw=False, # By default adata.raw.X is plotted. If use_raw=False is set, then adata.X is plotted. 
    cmap="inferno", # Alternative cmap: magma
    standard_scale="var", # standardize that dimension between 0 and 1, meaning for each variable or observation, subtract the minimum and divide each by its maximum
    swap_axes=False,
    figsize=(40, 10),
    save=True
)
# Out:
# /home/lauraluebbert/bin/miniconda3/lib/python3.7/site-packages/anndata/_core/anndata.py:1229: ImplicitModificationWarning: Initializing view as actual.
#   "Initializing view as actual.", ImplicitModificationWarning
# Trying to set attribute `.obs` of view, copying.
# ... storing 'batch_g' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'celltype_sep' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'connectivity_sep' as categorical
# WARNING: saving figure to file figures/heatmap.pdf

# %%
sc.pl.stacked_violin(adata[np.char.startswith(nd(adata.obs.celltype.values).astype(str), "glutamatergic neurons")], 
                     all_markers, 
                     groupby='connectivity', 
#                      title="Marker gene expression in connectivity clusters", 
                     rotation=90, 
                     sharey=True,
                     use_raw=False,
                     swap_axes=False,
                     save=True
#                      vmin=0,
#                      vmax=0.75
                    )
# Out:
# /home/lauraluebbert/bin/miniconda3/lib/python3.7/site-packages/anndata/_core/anndata.py:1229: ImplicitModificationWarning: Initializing view as actual.
#   "Initializing view as actual.", ImplicitModificationWarning
# Trying to set attribute `.obs` of view, copying.
# ... storing 'batch_g' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'celltype_sep' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'connectivity_sep' as categorical
# WARNING: saving figure to file figures/stacked_violin_.pdf

# %%
sc.pl.heatmap(
    adata,
    all_markers,
    groupby="celltype",
#     dendrogram=True, # This messes up the ordering of the celltypes
    show_gene_labels=True,
#     var_group_positions=var_groups,
#     var_group_labels=var_labels,
#     var_group_rotation=90,
    use_raw=False, # By default adata.raw.X is plotted. If use_raw=False is set, then adata.X is plotted. 
    cmap="inferno", # Alternative cmap: magma
    standard_scale="var", # standardize that dimension between 0 and 1, meaning for each variable or observation, subtract the minimum and divide each by its maximum
    swap_axes=False,
    figsize=(40, 40),
    save=True
)
# Out:
# WARNING: saving figure to file figures/heatmap.pdf
